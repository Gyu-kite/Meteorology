# %%
import datetime
from mpop.satellites import GeostationaryFactory
# Out:
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-10-a611ccaee94d>", line 2, in <module>
#     from mpop.satellites import GeostationaryFactory
#
#   File "/usr/local/lib/python3.8/dist-packages/mpop/satellites/__init__.py", line 70
#     def get_sat_instr_compositer((satellite, number, variant), instrument):
#                                  ^
# SyntaxError: invalid syntax

# %%
# !pip install mpop
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.2/331.2 KB 14.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 11.0 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.6/288.6 KB 29.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 106.8 MB/s eta 0:00:00
# ...
#   Created wheel for mpop: filename=mpop-1.5.1-py3-none-any.whl size=373461 sha256=3984c6888a349581f86b91c2036d4ce006f085d6cb619517aaee2c3261f529d7
#   Stored in directory: /root/.cache/pip/wheels/54/9b/41/9a006b10a9d1db066a8866c6f040cc7858aef2e4101c2c5c4c
# ...
#   Created wheel for configobj: filename=configobj-5.0.6-py3-none-any.whl size=34547 sha256=b5b579fd60c142efe022ea17a6b14cf9bd75b74eadb8de539454cdae8b379ca6
# ...
