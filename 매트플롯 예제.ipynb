# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 메소드1 객체지향 API사용

# %%
from matplotlib import figure
x = np.linspace(0,1,50)
y = np.cos(4*np.pi*x)

fig  = plt.figure()
ax= fig.subplots()
ax.plot(x,y)
